# %%
import matplotlib.pyplot as plt
from opensignalsreader import OpenSignalsReader

# %%
data1 = OpenSignalsReader("data_mal/DATOS.txt")
data2 = OpenSignalsReader("data_mal/DATOS_1.txt")
data3 = OpenSignalsReader("data_mal/DATOS_2.txt")
data4 = OpenSignalsReader("data_mal/DATOS_3.txt")
data5 = OpenSignalsReader("data_mal/DATOS_4.txt")
data6 = OpenSignalsReader("data_mal/DATOS_5.txt")
data7 = OpenSignalsReader("data_mal/DATOS_6.txt")
data8 = OpenSignalsReader("data_mal/DATOS_7.txt")
data9 = OpenSignalsReader("data_mal/DATOS_8.txt")
data10 = OpenSignalsReader("data_mal/DATOS_9.txt")
data11 = OpenSignalsReader("data_mal/DATOS_10.txt")
data12 = OpenSignalsReader("data_mal/DATOS_11.txt")

# %%
plt.figure(figsize=(15, 15))  # Establece el tamaño de la figura

for i in range(1, 13):  # Cambiamos el rango para 12 gráficas
    plt.subplot(4, 3, i)  # Crea un subplot de 4 filas y 3 columnas, y selecciona la i-ésima posición
    plt.plot(eval(f"data{i}").raw([1]))  # Plotea los datos correspondientes a data{i}
    plt.xlabel('Sample')
    plt.ylabel('Value')
    plt.title(f'Data {i}')

plt.tight_layout()  # Ajusta automáticamente el espaciado entre subplots para que no se solapen
plt.show()

# %%
for i in range(1, 13):  # Cambiamos el rango para 12 gráficas
    plt.plot(eval(f"data{i}").raw([1]))  # Plotea los datos correspondientes a data{i}
    plt.xlabel('Sample')
    plt.ylabel('Value')
    plt.title(f'Data {i}')
    plt.savefig(f"img_mal/data_{i}.png")
    plt.show()

# %%
data13 = OpenSignalsReader("data_bien/DATOS.txt")
data14 = OpenSignalsReader("data_bien/DATOS_1.txt")
data15 = OpenSignalsReader("data_bien/DATOS_2.txt")
data16 = OpenSignalsReader("data_bien/DATOS_3.txt")
data17 = OpenSignalsReader("data_bien/DATOS_4.txt")
data18 = OpenSignalsReader("data_bien/DATOS_5.txt")
data19 = OpenSignalsReader("data_bien/DATOS_6.txt")
data20 = OpenSignalsReader("data_bien/DATOS_7.txt")
data21 = OpenSignalsReader("data_bien/DATOS_8.txt")
data22 = OpenSignalsReader("data_bien/DATOS_9.txt")
data23 = OpenSignalsReader("data_bien/DATOS_10.txt")
data24 = OpenSignalsReader("data_bien/DATOS_11.txt")

# %%
plt.figure(figsize=(15, 15))  # Establece el tamaño de la figura


for i in range(1, 13):  # Cambiamos el rango para 12 gráficas
    plt.subplot(4, 3, i)  # Crea un subplot de 4 filas y 3 columnas, y selecciona la i-ésima posición
    plt.plot(eval(f"data{i+12}").raw([1]))  # Plotea los datos correspondientes a data{i}
    plt.xlabel('Sample')
    plt.ylabel('Value')
    plt.title(f'Data {i+12}')

plt.tight_layout()  # Ajusta automáticamente el espaciado entre subplots para que no se solapen
plt.show()

# %%
for i in range(1, 13):  # Cambiamos el rango para 12 gráficas
    plt.plot(eval(f"data{i+12}").raw([1]))  # Plotea los datos correspondientes a data{i}
    plt.xlabel('Sample')
    plt.ylabel('Value')
    plt.title(f'Data {i+12}')
    plt.savefig(f"img_bien/data_{i+12}.png")
    plt.show()
